# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
#
# - As expected temperature increases as we approach the equator (0 Deg. Latitude).
# - City Latitude vs cloudiness Plot shows that cloudiness are somewhat indifferent to Latitudes, but it is interesting to see that a a number of cities sits at between 20 to 80 Latitude with 100% cloudiness.
# - City Latitude vs Windspeed Plot shows that Windspeeds are somewhat indifferent to Latitudes, but it is important to note that highest wind speed occur at latitudes furthest from the equator at alomost with over 25 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# Create a df to lat, lon 
column_names = ["City", "Country"]
cities_df = pd.DataFrame(columns=column_names)
cities_df
# Out:
# Empty DataFrame
# Columns: [City, Country]
# Index: []

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 596

# %% [markdown]
# ## Generate Cities List

# %%
# Randomly generate a list of 500 cities. Use 50 to test for duplicates.# Rando 
for x in range(1500):
    lat, lng = np.random.uniform(low=-90.000, high=90.000), np.random.uniform(low=-180.000, high=180.000)
    city = citipy.nearest_city(lat, lng)
    cities_df = cities_df.append({"City": city.city_name,"Country": city.country_code,}, ignore_index=True)

#Remove duplicate cities
cities_df = cities_df.drop_duplicates(subset='City').reset_index()
cities_df.count()
# Out:
# index      595
# City       595
# Country    595
# dtype: int64

# %%
#Create a df to add all the data from the API calls.
column_names = ["City","Country","Temperature (F)",
                "Latitude","Longitude","Humidity (%)",
                "Cloudiness (%)", "Wind Speed (mph)"]
clean_cities_df = pd.DataFrame(columns=column_names)
clean_cities_df.head()
# Out:
# Empty DataFrame
# Columns: [City, Country, Temperature (F), Latitude, Longitude, Humidity (%), Cloudiness (%), Wind Speed (mph)]
# Index: []

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# OpenWeatherMap API Key
api_key = "4d0de241d02dabb93cd2fbbf60c865a6"


# Loop through the list of cities and add the data to the df. 
url = "http://api.openweathermap.org/data/2.5/weather?"

row_count = 1

print("Beginning Data Retrieval")
for index, row in cities_df.iterrows():
    target_city = row["City"]
    target_url = url + "appid=" + api_key + "&units=IMPERIAL" + "&q=" + target_city.replace(" ","+")
    city_data = requests.get(target_url).json()
    if city_data["cod"] == "404":
        print("City not found, skipping...")

    else:
        clean_cities_df.set_value(index, "City", city_data["name"])
        clean_cities_df.set_value(index, "Country", city_data["sys"]["country"])
        clean_cities_df.set_value(index, "Temperature (F)", city_data["main"]["temp"])
        clean_cities_df.set_value(index, "Latitude", city_data["coord"]["lat"])
        clean_cities_df.set_value(index, "Longitude", city_data["coord"]["lon"])
        clean_cities_df.set_value(index, "Humidity (%)", city_data["main"]["humidity"])
        clean_cities_df.set_value(index, "Cloudiness (%)", city_data["clouds"]["all"])
        clean_cities_df.set_value(index, "Wind Speed (mph)", city_data["wind"]["speed"])
        
        print("------------------------")
        print("Proceesing: City # " , row_count, ' | ' , city_data["name"], city_data["sys"]["country"])
        print(target_url)
        row_count += 1
# Out:
# Beginning Data Retrieval
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:20: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:21: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:23: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:25: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:26: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# ------------------------
# Proceesing: City #  1  |  Rikitea PF
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=rikitea
# ------------------------
# Proceesing: City #  2  |  Dhidhdhoo MV
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=dhidhdhoo
# ------------------------
# Proceesing: City #  3  |  Nerchinskiy Zavod RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=nerchinskiy+zavod
# ------------------------
# Proceesing: City #  4  |  Busselton AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=busselton
# ------------------------
# Proceesing: City #  5  |  Batemans Bay AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=batemans+bay
# ------------------------
# Proceesing: City #  6  |  Yatou CM
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=yatou
# ------------------------
# Proceesing: City #  7  |  Umm Lajj SA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=umm+lajj
# City not found, skipping...
# ------------------------
# Proceesing: City #  8  |  Cravo Norte CO
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=cravo+norte
# ------------------------
# Proceesing: City #  9  |  Yeppoon AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=yeppoon
# ------------------------
# Proceesing: City #  10  |  Hobart AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=hobart
# ------------------------
# Proceesing: City #  11  |  Port Blair IN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=port+blair
# ------------------------
# Proceesing: City #  12  |  Palmer AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=palmer
# ------------------------
# Proceesing: City #  13  |  Klaksvik FO
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=klaksvik
# ------------------------
# Proceesing: City #  14  |  San Quintin PH
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=san+quintin
# ------------------------
# Proceesing: City #  15  |  Atuona PF
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=atuona
# ------------------------
# Proceesing: City #  16  |  Hilo US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=hilo
# ------------------------
# Proceesing: City #  17  |  Ushuaia AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ushuaia
# ------------------------
# Proceesing: City #  18  |  Katsuura JP
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=katsuura
# ------------------------
# Proceesing: City #  19  |  Cape Town ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=cape+town
# ------------------------
# Proceesing: City #  20  |  Cabo San Lucas MX
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=cabo+san+lucas
# ------------------------
# Proceesing: City #  21  |  Haines Junction CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=haines+junction
# ------------------------
# Proceesing: City #  22  |  Vaini IN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=vaini
# ------------------------
# Proceesing: City #  23  |  Havre-Saint-Pierre CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=havre-saint-pierre
# City not found, skipping...
# ------------------------
# Proceesing: City #  24  |  Mataura NZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mataura
# ------------------------
# Proceesing: City #  25  |  Mollendo PE
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mollendo
# ------------------------
# Proceesing: City #  26  |  Avarua CK
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=avarua
# ------------------------
# Proceesing: City #  27  |  Lebu ET
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=lebu
# ------------------------
# Proceesing: City #  28  |  Namibe AO
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=namibe
# ------------------------
# Proceesing: City #  29  |  Halifax CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=halifax
# ------------------------
# Proceesing: City #  30  |  Victoria BN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=victoria
# ------------------------
# Proceesing: City #  31  |  Bol TD
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=bol
# ------------------------
# Proceesing: City #  32  |  Alyangula AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=alyangula
# ------------------------
# Proceesing: City #  33  |  Sao Paulo de Olivenca BR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=sao+paulo+de+olivenca
# ------------------------
# Proceesing: City #  34  |  San Patricio PY
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=san+patricio
# ------------------------
# Proceesing: City #  35  |  Severo-Kurilsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=severo-kurilsk
# ------------------------
# Proceesing: City #  36  |  Yokadouma CM
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=yokadouma
# ------------------------
# Proceesing: City #  37  |  College US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=college
# ------------------------
# Proceesing: City #  38  |  Bambous Virieux MU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=bambous+virieux
# ------------------------
# Proceesing: City #  39  |  Ballina IE
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ballina
# ------------------------
# Proceesing: City #  40  |  Albany US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=albany
# ------------------------
# Proceesing: City #  41  |  Taoudenni ML
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=taoudenni
# ------------------------
# Proceesing: City #  42  |  Butaritari KI
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=butaritari
# ------------------------
# Proceesing: City #  43  |  Mar del Plata AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mar+del+plata
# ------------------------
# Proceesing: City #  44  |  San Rafael AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=san+rafael
# ------------------------
# Proceesing: City #  45  |  Invermere CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=invermere
# ------------------------
# Proceesing: City #  46  |  Kiama AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=kiama
# ------------------------
# Proceesing: City #  47  |  Cidreira BR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=cidreira
# ------------------------
# Proceesing: City #  48  |  Praia da Vitoria PT
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=praia+da+vitoria
# ------------------------
# Proceesing: City #  49  |  Hermanus ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=hermanus
# City not found, skipping...
# ------------------------
# Proceesing: City #  50  |  Waingapu ID
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=waingapu
# ------------------------
# Proceesing: City #  51  |  Pacific Grove US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=pacific+grove
# ------------------------
# Proceesing: City #  52  |  Jiuquan CN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=jiuquan
# ------------------------
# Proceesing: City #  53  |  Labuhan ID
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=labuhan
# ------------------------
# Proceesing: City #  54  |  Ternate PH
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ternate
# ------------------------
# Proceesing: City #  55  |  Saint-Francois FR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=saint-francois
# ------------------------
# Proceesing: City #  56  |  Castro CL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=castro
# ------------------------
# Proceesing: City #  57  |  Coahuayana MX
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=coahuayana
# ------------------------
# Proceesing: City #  58  |  Kapaa US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=kapaa
# ------------------------
# Proceesing: City #  59  |  Henties Bay NA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=henties+bay
# ------------------------
# Proceesing: City #  60  |  Sioux Lookout CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=sioux+lookout
# ------------------------
# Proceesing: City #  61  |  Blythe US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=blythe
# ------------------------
# Proceesing: City #  62  |  Mackay CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mackay
# ------------------------
# Proceesing: City #  63  |  Beyneu KZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=beyneu
# ------------------------
# Proceesing: City #  64  |  Maldonado UY
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=maldonado
# ------------------------
# Proceesing: City #  65  |  Samarai PG
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=samarai
# ------------------------
# Proceesing: City #  66  |  Caravelas BR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=caravelas
# ------------------------
# Proceesing: City #  67  |  Buraydah SA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=buraydah
# ------------------------
# Proceesing: City #  68  |  Manjacaze MZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=manjacaze
# ------------------------
# Proceesing: City #  69  |  Contai IN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=contai
# ------------------------
# Proceesing: City #  70  |  Atasu KZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=atasu
# ------------------------
# Proceesing: City #  71  |  Saint-Philippe CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=saint-philippe
# ------------------------
# Proceesing: City #  72  |  Sola FI
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=sola
# City not found, skipping...
# ------------------------
# Proceesing: City #  73  |  Jamestown AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=jamestown
# ------------------------
# Proceesing: City #  74  |  Danilov RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=danilov
# City not found, skipping...
# ------------------------
# Proceesing: City #  75  |  Bilibino RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=bilibino
# City not found, skipping...
# ------------------------
# Proceesing: City #  76  |  Witu KE
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=witu
# City not found, skipping...
# ------------------------
# Proceesing: City #  77  |  Egvekinot RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=egvekinot
# ------------------------
# Proceesing: City #  78  |  Belmopan BZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=belmopan
# City not found, skipping...
# ------------------------
# Proceesing: City #  79  |  Hovd NO
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=hovd
# City not found, skipping...
# ------------------------
# Proceesing: City #  80  |  Punta Arenas CL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=punta+arenas
# ------------------------
# Proceesing: City #  81  |  Torres BR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=torres
# ------------------------
# Proceesing: City #  82  |  Jijiang CN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=jijiang
# ------------------------
# Proceesing: City #  83  |  Arraial do Cabo BR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=arraial+do+cabo
# City not found, skipping...
# ------------------------
# Proceesing: City #  84  |  Santa Maria BR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=santa+maria
# ------------------------
# Proceesing: City #  85  |  Fare PF
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=fare
# ------------------------
# Proceesing: City #  86  |  Kavaratti IN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=kavaratti
# ------------------------
# Proceesing: City #  87  |  Port Hardy CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=port+hardy
# ------------------------
# Proceesing: City #  88  |  Ribeira Grande PT
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ribeira+grande
# ------------------------
# Proceesing: City #  89  |  Verkhoyansk RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=verkhoyansk
# ------------------------
# Proceesing: City #  90  |  Chifeng CN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=chifeng
# ------------------------
# Proceesing: City #  91  |  Geraldton CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=geraldton
# ------------------------
# Proceesing: City #  92  |  Nabire ID
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=nabire
# ------------------------
# Proceesing: City #  93  |  Port Elizabeth US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=port+elizabeth
# City not found, skipping...
# ------------------------
# Proceesing: City #  94  |  Kodiak US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=kodiak
# ------------------------
# Proceesing: City #  95  |  Boyuibe BO
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=boyuibe
# ------------------------
# Proceesing: City #  96  |  Areosa PT
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=areosa
# ------------------------
# Proceesing: City #  97  |  Rupert US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=rupert
# ------------------------
# Proceesing: City #  98  |  Batagay-Alyta RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=batagay-alyta
# ------------------------
# Proceesing: City #  99  |  Haputale LK
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=haputale
# City not found, skipping...
# ------------------------
# Proceesing: City #  100  |  Tasiilaq GL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=tasiilaq
# ------------------------
# Proceesing: City #  101  |  Dvinskoy RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=dvinskoy
# ------------------------
# Proceesing: City #  102  |  Yellowknife CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=yellowknife
# ------------------------
# Proceesing: City #  103  |  Anadyr RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=anadyr
# ------------------------
# Proceesing: City #  104  |  Majene ID
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=majene
# ------------------------
# Proceesing: City #  105  |  Kutum SD
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=kutum
# City not found, skipping...
# ------------------------
# Proceesing: City #  106  |  Georgetown GY
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=georgetown
# ------------------------
# Proceesing: City #  107  |  Manzanillo CU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=manzanillo
# ------------------------
# Proceesing: City #  108  |  Dharchula IN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=dharchula
# City not found, skipping...
# ------------------------
# Proceesing: City #  109  |  Chuy UY
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=chuy
# ------------------------
# Proceesing: City #  110  |  Saldanha PT
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=saldanha
# ------------------------
# Proceesing: City #  111  |  Shelburne CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=shelburne
# ------------------------
# Proceesing: City #  112  |  Barrow AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=barrow
# ------------------------
# Proceesing: City #  113  |  Upernavik GL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=upernavik
# ------------------------
# Proceesing: City #  114  |  Mastic Beach US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mastic+beach
# ------------------------
# Proceesing: City #  115  |  Talas TR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=talas
# ------------------------
# Proceesing: City #  116  |  Fortuna ES
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=fortuna
# ------------------------
# Proceesing: City #  117  |  Svobodnyy RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=svobodnyy
# ------------------------
# Proceesing: City #  118  |  New Norfolk AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=new+norfolk
# ------------------------
# Proceesing: City #  119  |  Whyalla AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=whyalla
# City not found, skipping...
# ------------------------
# Proceesing: City #  120  |  Cervo BR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=cervo
# ------------------------
# Proceesing: City #  121  |  Tuatapere NZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=tuatapere
# ------------------------
# Proceesing: City #  122  |  Los Llanos de Aridane ES
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=los+llanos+de+aridane
# ------------------------
# Proceesing: City #  123  |  Mersing MY
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mersing
# ------------------------
# Proceesing: City #  124  |  Boshan CN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=boshan
# ------------------------
# Proceesing: City #  125  |  Road Town VG
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=road+town
# ------------------------
# Proceesing: City #  126  |  Aden YE
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=aden
# ------------------------
# Proceesing: City #  127  |  Kaoma ZM
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=kaoma
# ------------------------
# Proceesing: City #  128  |  Luderitz NA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=luderitz
# ------------------------
# Proceesing: City #  129  |  Puerto Escondido MX
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=puerto+escondido
# ------------------------
# Proceesing: City #  130  |  Iwaki JP
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=iwaki
# ------------------------
# Proceesing: City #  131  |  Sainte-Maxime FR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=sainte-maxime
# ------------------------
# Proceesing: City #  132  |  Navalmoral de la Mata ES
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=navalmoral+de+la+mata
# ------------------------
# Proceesing: City #  133  |  Esperance TT
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=esperance
# City not found, skipping...
# ------------------------
# Proceesing: City #  134  |  Kahului US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=kahului
# ------------------------
# Proceesing: City #  135  |  Bluff AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=bluff
# ------------------------
# Proceesing: City #  136  |  Aksarka RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=aksarka
# ------------------------
# Proceesing: City #  137  |  Khatanga RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=khatanga
# ------------------------
# Proceesing: City #  138  |  Slave Lake CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=slave+lake
# City not found, skipping...
# ------------------------
# Proceesing: City #  139  |  Meadow Lake CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=meadow+lake
# ------------------------
# Proceesing: City #  140  |  Chokurdakh RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=chokurdakh
# ------------------------
# Proceesing: City #  141  |  Avera US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=avera
# ------------------------
# Proceesing: City #  142  |  Nikolskoye RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=nikolskoye
# ------------------------
# Proceesing: City #  143  |  Adrar DZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=adrar
# ------------------------
# Proceesing: City #  144  |  Gualeguaychu AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=gualeguaychu
# ------------------------
# Proceesing: City #  145  |  Vao EE
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=vao
# ------------------------
# Proceesing: City #  146  |  Ponta do Sol BR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ponta+do+sol
# ------------------------
# Proceesing: City #  147  |  Iranshahr IR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=iranshahr
# ------------------------
# Proceesing: City #  148  |  Souillac FR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=souillac
# ------------------------
# Proceesing: City #  149  |  Pallasovka RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=pallasovka
# ------------------------
# Proceesing: City #  150  |  Sur OM
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=sur
# ------------------------
# Proceesing: City #  151  |  Pevek RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=pevek
# ------------------------
# Proceesing: City #  152  |  Dikson RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=dikson
# ------------------------
# Proceesing: City #  153  |  Airai TL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=airai
# ------------------------
# Proceesing: City #  154  |  Bolotnoye RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=bolotnoye
# ------------------------
# Proceesing: City #  155  |  Sobolevo RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=sobolevo
# ------------------------
# Proceesing: City #  156  |  Grand-Santi GF
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=grand-santi
# ------------------------
# Proceesing: City #  157  |  Bud NO
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=bud
# ------------------------
# Proceesing: City #  158  |  Mount Isa AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mount+isa
# ------------------------
# Proceesing: City #  159  |  Qaanaaq GL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=qaanaaq
# ------------------------
# Proceesing: City #  160  |  High Level CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=high+level
# ------------------------
# Proceesing: City #  161  |  Miyang CN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=miyang
# ------------------------
# Proceesing: City #  162  |  Biak ID
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=biak
# ------------------------
# Proceesing: City #  163  |  Kavieng PG
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=kavieng
# City not found, skipping...
# ------------------------
# Proceesing: City #  164  |  Porto Novo BR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=porto+novo
# ------------------------
# Proceesing: City #  165  |  Lavrentiya RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=lavrentiya
# ------------------------
# Proceesing: City #  166  |  Dunedin NZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=dunedin
# ------------------------
# Proceesing: City #  167  |  Verkhnyaya Inta RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=verkhnyaya+inta
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  168  |  Muzhi RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=muzhi
# ------------------------
# Proceesing: City #  169  |  The Valley AI
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=the+valley
# ------------------------
# Proceesing: City #  170  |  Nelson Bay AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=nelson+bay
# City not found, skipping...
# ------------------------
# Proceesing: City #  171  |  Port Alfred ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=port+alfred
# ------------------------
# Proceesing: City #  172  |  Dukat RS
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=dukat
# ------------------------
# Proceesing: City #  173  |  Tabou CI
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=tabou
# ------------------------
# Proceesing: City #  174  |  Kapustin Yar RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=kapustin+yar
# ------------------------
# Proceesing: City #  175  |  Grand Gaube MU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=grand+gaube
# ------------------------
# Proceesing: City #  176  |  Mindelo PT
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mindelo
# ------------------------
# Proceesing: City #  177  |  North Bend US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=north+bend
# ------------------------
# Proceesing: City #  178  |  Lagoa PT
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=lagoa
# ------------------------
# Proceesing: City #  179  |  Chama ZM
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=chama
# ------------------------
# Proceesing: City #  180  |  Menongue AO
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=menongue
# ------------------------
# Proceesing: City #  181  |  Thompson CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=thompson
# ------------------------
# Proceesing: City #  182  |  Torbay CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=torbay
# ------------------------
# Proceesing: City #  183  |  Iqaluit CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=iqaluit
# ------------------------
# Proceesing: City #  184  |  Kargala RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=kargala
# ------------------------
# Proceesing: City #  185  |  Tuktoyaktuk CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=tuktoyaktuk
# ------------------------
# Proceesing: City #  186  |  Lebanon US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=lebanon
# ------------------------
# Proceesing: City #  187  |  Bereda ES
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=bereda
# ------------------------
# Proceesing: City #  188  |  Mehran IR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mehran
# ------------------------
# Proceesing: City #  189  |  Raudeberg NO
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=raudeberg
# ------------------------
# Proceesing: City #  190  |  Talaya RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=talaya
# ------------------------
# Proceesing: City #  191  |  Zakamensk RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=zakamensk
# ------------------------
# Proceesing: City #  192  |  Acapulco MX
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=acapulco
# ------------------------
# Proceesing: City #  193  |  Macusani PE
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=macusani
# City not found, skipping...
# ------------------------
# Proceesing: City #  194  |  Bangassou CF
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=bangassou
# ------------------------
# Proceesing: City #  195  |  Guerrero Negro MX
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=guerrero+negro
# ------------------------
# Proceesing: City #  196  |  Bethel US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=bethel
# ------------------------
# Proceesing: City #  197  |  Ahuimanu US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ahuimanu
# City not found, skipping...
# ------------------------
# Proceesing: City #  198  |  Maniitsoq GL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=maniitsoq
# ------------------------
# Proceesing: City #  199  |  Tiksi RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=tiksi
# ------------------------
# Proceesing: City #  200  |  Shingu JP
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=shingu
# ------------------------
# Proceesing: City #  201  |  Alofi NU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=alofi
# ------------------------
# Proceesing: City #  202  |  Pisco PE
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=pisco
# ------------------------
# Proceesing: City #  203  |  Verkhnevilyuysk RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=verkhnevilyuysk
# ------------------------
# Proceesing: City #  204  |  Morahalom HU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=morahalom
# ------------------------
# Proceesing: City #  205  |  Tessalit ML
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=tessalit
# ------------------------
# Proceesing: City #  206  |  Namatanai PG
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=namatanai
# ------------------------
# Proceesing: City #  207  |  Acajutla SV
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=acajutla
# ------------------------
# Proceesing: City #  208  |  Salamiyah SY
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=salamiyah
# ------------------------
# Proceesing: City #  209  |  Pochutla MX
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=pochutla
# ------------------------
# Proceesing: City #  210  |  Makakilo City US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=makakilo+city
# ------------------------
# Proceesing: City #  211  |  Baykit RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=baykit
# ------------------------
# Proceesing: City #  212  |  Neryungri RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=neryungri
# ------------------------
# Proceesing: City #  213  |  Port Lincoln AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=port+lincoln
# City not found, skipping...
# ------------------------
# Proceesing: City #  214  |  Abha SA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=abha
# ------------------------
# Proceesing: City #  215  |  Ostrovnoy RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ostrovnoy
# ------------------------
# Proceesing: City #  216  |  San Cristobal EC
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=san+cristobal
# ------------------------
# Proceesing: City #  217  |  Lompoc US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=lompoc
# ------------------------
# Proceesing: City #  218  |  Cap Malheureux MU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=cap+malheureux
# ------------------------
# Proceesing: City #  219  |  Norman Wells CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=norman+wells
# ------------------------
# Proceesing: City #  220  |  Vaitape PF
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=vaitape
# ------------------------
# Proceesing: City #  221  |  Chapleau CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=chapleau
# ------------------------
# Proceesing: City #  222  |  Lubao PH
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=lubao
# ------------------------
# Proceesing: City #  223  |  Flin Flon CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=flin+flon
# ------------------------
# Proceesing: City #  224  |  Santa Isabel do Rio Negro BR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=santa+isabel+do+rio+negro
# ------------------------
# Proceesing: City #  225  |  Kwinana AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=kwinana
# ------------------------
# Proceesing: City #  226  |  Petatlan MX
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=petatlan
# ------------------------
# Proceesing: City #  227  |  Valle de Allende MX
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=valle+de+allende
# ------------------------
# Proceesing: City #  228  |  Saskylakh RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=saskylakh
# ------------------------
# Proceesing: City #  229  |  Bredasdorp ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=bredasdorp
# ------------------------
# Proceesing: City #  230  |  Nortelandia BR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=nortelandia
# ------------------------
# Proceesing: City #  231  |  Pareora NZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=pareora
# City not found, skipping...
# ------------------------
# Proceesing: City #  232  |  Rusape ZW
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=rusape
# ------------------------
# Proceesing: City #  233  |  Trelew AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=trelew
# ------------------------
# Proceesing: City #  234  |  Puerto Ayora EC
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=puerto+ayora
# ------------------------
# Proceesing: City #  235  |  Vostok RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=vostok
# ------------------------
# Proceesing: City #  236  |  Saint George GR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=saint+george
# ------------------------
# Proceesing: City #  237  |  Senanga ZM
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=senanga
# ------------------------
# Proceesing: City #  238  |  Pangnirtung CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=pangnirtung
# ------------------------
# Proceesing: City #  239  |  Dalbandin PK
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=dalbandin
# ------------------------
# Proceesing: City #  240  |  Ilulissat GL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ilulissat
# ------------------------
# Proceesing: City #  241  |  Decatur US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=decatur
# ------------------------
# Proceesing: City #  242  |  Faanui PF
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=faanui
# ------------------------
# Proceesing: City #  243  |  Xining CN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=xining
# ------------------------
# Proceesing: City #  244  |  Tura IN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=tura
# ------------------------
# Proceesing: City #  245  |  Fomboni KM
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=fomboni
# ------------------------
# Proceesing: City #  246  |  Grindavik IS
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=grindavik
# ------------------------
# Proceesing: City #  247  |  Westport IE
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=westport
# City not found, skipping...
# ------------------------
# Proceesing: City #  248  |  Corinth GR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=corinth
# ------------------------
# Proceesing: City #  249  |  Adre TD
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=adre
# ------------------------
# Proceesing: City #  250  |  Sorland NO
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=sorland
# ------------------------
# Proceesing: City #  251  |  Pleasanton US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=pleasanton
# ------------------------
# Proceesing: City #  252  |  Yulara AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=yulara
# City not found, skipping...
# ------------------------
# Proceesing: City #  253  |  Leningradskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=leningradskiy
# ------------------------
# Proceesing: City #  254  |  Waipawa NZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=waipawa
# ------------------------
# Proceesing: City #  255  |  Matagami NG
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=matagami
# ------------------------
# Proceesing: City #  256  |  Nampula MZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=nampula
# ------------------------
# Proceesing: City #  257  |  Berlevag NO
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=berlevag
# ------------------------
# ...
# ------------------------
# Proceesing: City #  454  |  Tazovskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=tazovskiy
# ------------------------
# Proceesing: City #  455  |  Cochrane CL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=cochrane
# City not found, skipping...
# ------------------------
# Proceesing: City #  456  |  Nishihara JP
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=nishihara
# ------------------------
# Proceesing: City #  457  |  Mahon IE
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mahon
# ------------------------
# Proceesing: City #  458  |  Coihaique CL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=coihaique
# ------------------------
# Proceesing: City #  459  |  Abapo BO
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=abapo
# ------------------------
# Proceesing: City #  460  |  Kysyl-Syr RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=kysyl-syr
# ------------------------
# Proceesing: City #  461  |  Ulladulla AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ulladulla
# ------------------------
# Proceesing: City #  462  |  Alenquer BR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=alenquer
# ------------------------
# Proceesing: City #  463  |  Pontes e Lacerda BR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=pontes+e+lacerda
# ------------------------
# Proceesing: City #  464  |  Mayumba GA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mayumba
# ------------------------
# Proceesing: City #  465  |  Herat AF
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=herat
# ------------------------
# Proceesing: City #  466  |  Pozo Colorado PY
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=pozo+colorado
# ------------------------
# Proceesing: City #  467  |  Ambunti PG
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ambunti
# ------------------------
# Proceesing: City #  468  |  Methoni GR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=methoni
# ------------------------
# Proceesing: City #  469  |  Gorom-Gorom BF
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=gorom-gorom
# ------------------------
# Proceesing: City #  470  |  Okha RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=okha
# ------------------------
# Proceesing: City #  471  |  Shenjiamen CN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=shenjiamen
# ------------------------
# Proceesing: City #  472  |  Savelugu GH
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=savelugu
# ------------------------
# Proceesing: City #  473  |  Dryden CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=dryden
# ------------------------
# Proceesing: City #  474  |  Marawi PH
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=marawi
# ------------------------
# Proceesing: City #  475  |  Nianzishan CN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=nianzishan
# ------------------------
# Proceesing: City #  476  |  Manggar ID
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=manggar
# City not found, skipping...
# ------------------------
# Proceesing: City #  477  |  Ca Mau VN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ca+mau
# ------------------------
# Proceesing: City #  478  |  Perth GB
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=perth
# ------------------------
# Proceesing: City #  479  |  Dubti ET
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=dubti
# ------------------------
# Proceesing: City #  480  |  Ust-Tsilma RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ust-tsilma
# ------------------------
# Proceesing: City #  481  |  Soledade BR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=soledade
# ------------------------
# Proceesing: City #  482  |  Long Beach US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=long+beach
# ------------------------
# Proceesing: City #  483  |  Mwene-Ditu CD
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mwene-ditu
# ------------------------
# Proceesing: City #  484  |  Bhindar PK
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=bhindar
# ------------------------
# Proceesing: City #  485  |  Itoman JP
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=itoman
# ------------------------
# Proceesing: City #  486  |  Kouango CF
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=kouango
# ------------------------
# Proceesing: City #  487  |  Pendleton US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=pendleton
# ------------------------
# Proceesing: City #  488  |  Ati TD
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ati
# ------------------------
# Proceesing: City #  489  |  Melilla EC
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=melilla
# City not found, skipping...
# ------------------------
# Proceesing: City #  490  |  Yekaterinoslavka RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=yekaterinoslavka
# ------------------------
# Proceesing: City #  491  |  Aktau KZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=aktau
# City not found, skipping...
# ------------------------
# Proceesing: City #  492  |  Nanlong CN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=nanlong
# ------------------------
# Proceesing: City #  493  |  Nioro GM
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=nioro
# ------------------------
# Proceesing: City #  494  |  Vestmanna FO
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=vestmanna
# ------------------------
# Proceesing: City #  495  |  Inhambane MZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=inhambane
# ------------------------
# Proceesing: City #  496  |  Brae GB
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=brae
# ------------------------
# Proceesing: City #  497  |  Tabuny RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=tabuny
# ------------------------
# Proceesing: City #  498  |  Ouango CD
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ouango
# ------------------------
# Proceesing: City #  499  |  Plastun RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=plastun
# ------------------------
# Proceesing: City #  500  |  Charcas MX
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=charcas
# ------------------------
# Proceesing: City #  501  |  Iralaya HN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=iralaya
# ------------------------
# Proceesing: City #  502  |  Nuuk GL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=nuuk
# ------------------------
# Proceesing: City #  503  |  Tamale GH
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=tamale
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  504  |  Souris CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=souris
# ------------------------
# Proceesing: City #  505  |  Jambi ID
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=jambi
# ------------------------
# Proceesing: City #  506  |  Boysun UZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=boysun
# ------------------------
# Proceesing: City #  507  |  Khandbari NP
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=khandbari
# ------------------------
# Proceesing: City #  508  |  Burnie AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=burnie
# ------------------------
# Proceesing: City #  509  |  Shahreza IR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=shahreza
# ------------------------
# Proceesing: City #  510  |  Rio Pomba BR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=rio+pomba
# ------------------------
# Proceesing: City #  511  |  Lyskovo RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=lyskovo
# ------------------------
# Proceesing: City #  512  |  Lazaro Cardenas MX
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=lazaro+cardenas
# ------------------------
# Proceesing: City #  513  |  Anchorage US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=anchorage
# ------------------------
# Proceesing: City #  514  |  Broome GB
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=broome
# ------------------------
# Proceesing: City #  515  |  Palpa PE
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=palpa
# ------------------------
# Proceesing: City #  516  |  Kedougou SN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=kedougou
# ------------------------
# Proceesing: City #  517  |  Ancud CL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ancud
# ------------------------
# Proceesing: City #  518  |  Severo-Yeniseyskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=severo-yeniseyskiy
# ------------------------
# Proceesing: City #  519  |  Rawson AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=rawson
# ------------------------
# Proceesing: City #  520  |  Balyaga RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=balyaga
# ------------------------
# Proceesing: City #  521  |  Abbeville FR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=abbeville
# ------------------------
# Proceesing: City #  522  |  Parrita CR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=parrita
# ------------------------
# Proceesing: City #  523  |  Montepuez MZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=montepuez
# City not found, skipping...
# ------------------------
# Proceesing: City #  524  |  Deputatskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=deputatskiy
# ------------------------
# Proceesing: City #  525  |  Nola CF
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=nola
# ------------------------
# Proceesing: City #  526  |  Diego de Almagro CL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=diego+de+almagro
# ------------------------
# Proceesing: City #  527  |  Portland US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=portland
# ------------------------
# Proceesing: City #  528  |  Cartagena del Chaira CO
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=cartagena+del+chaira
# ------------------------
# Proceesing: City #  529  |  Liverpool GB
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=liverpool
# ------------------------
# Proceesing: City #  530  |  Kotelnikovo RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=kotelnikovo
# ------------------------
# Proceesing: City #  531  |  Santa Isabel CO
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=santa+isabel
# ------------------------
# Proceesing: City #  532  |  Vanimo PG
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=vanimo
# ------------------------
# Proceesing: City #  533  |  Mogadishu SO
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mogadishu
# ------------------------
# Proceesing: City #  534  |  Tacna PE
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=tacna
# ------------------------
# Proceesing: City #  535  |  Atar MR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=atar
# ------------------------
# Proceesing: City #  536  |  Margate AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=margate
# ------------------------
# Proceesing: City #  537  |  Vila Franca do Campo PT
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=vila+franca+do+campo
# ------------------------
# Proceesing: City #  538  |  Camacha PT
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=camacha
# ------------------------
# Proceesing: City #  539  |  Billings US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=billings
# ------------------------
# Proceesing: City #  540  |  Lithgow AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=lithgow
# ------------------------
# Proceesing: City #  541  |  Upata VE
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=upata
# ------------------------
# Proceesing: City #  542  |  Cockburn Town TC
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=cockburn+town

# %%
clean_cities_df.count()
# Out:
# City                542
# Country             542
# Temperature (F)     542
# Latitude            542
# Longitude           542
# Humidity (%)        542
# Cloudiness (%)      542
# Wind Speed (mph)    542
# dtype: int64

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
clean_cities_df
# Out:
#                      City Country Temperature (F) Latitude Longitude  \
# 0                 Rikitea      PF           73.41   -23.12   -134.97
# 1               Dhidhdhoo      MV           83.58     6.88      73.1
# 2       Nerchinskiy Zavod      RU           67.02    51.31    119.61
# 3               Busselton      AU           58.56   -33.64    115.35
# 4            Batemans Bay      AU           68.91   -35.71    150.18
# 5                   Yatou      CM            75.2     3.63      9.81
# 6                Umm Lajj      SA           85.92    25.02     37.27
# 8             Cravo Norte      CO           75.84      6.3     -70.2
# 9                 Yeppoon      AU              77   -23.13    150.74
# 10                 Hobart      AU            66.2   -42.88    147.33
# 11             Port Blair      IN           83.13    11.67     92.75
# 12                 Palmer      AU            60.8   -34.85    139.16
# 13               Klaksvik      FO            48.2    62.23     -6.59
# 14            San Quintin      PH              86    17.54    120.52
# 15                 Atuona      PF           78.54     -9.8   -139.03
# 16                   Hilo      US           67.87    19.71   -155.08
# 17                Ushuaia      AR            42.8   -54.81    -68.31
# 18               Katsuura      JP            78.8    33.93     134.5
# 19              Cape Town      ZA            42.8   -33.93     18.42
# 20         Cabo San Lucas      MX              77    22.89   -109.91
# 21        Haines Junction      CA           38.94    60.75   -137.51
# 22                  Vaini      IN           78.45    15.34     74.49
# 23     Havre-Saint-Pierre      CA            37.4    50.23     -63.6
# 25                Mataura      NZ            48.3   -46.19    168.86
# 26               Mollendo      PE           48.39   -17.03    -72.02
# 27                 Avarua      CK            75.2   -21.21   -159.78
# 28                   Lebu      ET           61.98     8.96     38.73
# 29                 Namibe      AO           62.43   -15.19     12.15
# 30                Halifax      CA            51.8    44.65    -63.58
# 31               Victoria      BN           86.92     5.28    115.24
# ..                    ...     ...             ...      ...       ...
# 564             Anchorage      US           54.16    61.22   -149.89
# 565                Broome      GB           61.48    52.47      1.45
# 566                 Palpa      PE           42.18   -14.53    -75.19
# 567              Kedougou      SN           71.34    12.56    -12.19
# 568                 Ancud      CL           49.65   -41.87    -73.83
# 569    Severo-Yeniseyskiy      RU           45.96    60.37     93.04
# 570                Rawson      AR           54.24    -43.3    -65.11
# 571               Balyaga      RU           47.67    51.15    108.93
# 572             Abbeville      FR           58.78    50.11      1.83
# 573               Parrita      CR            66.2     9.52    -84.33
# 574             Montepuez      MZ           70.35   -13.13        39
# 576           Deputatskiy      RU            33.9     69.3     139.9
# 577                  Nola      CF           68.91     3.52     16.05
# 578      Diego de Almagro      CL           49.38   -26.39    -70.05
# 579              Portland      US           59.25    45.52   -122.67
# 580  Cartagena del Chaira      CO           74.49     1.33    -74.84
# 581             Liverpool      GB            55.4    53.41     -2.98
# 582           Kotelnikovo      RU           74.13    47.63     43.14
# 583          Santa Isabel      CO           58.47     4.71     -75.1
# 584                Vanimo      PG           81.87    -2.67     141.3
# 585             Mogadishu      SO           77.01     2.04     45.34
# 586                 Tacna      PE           58.33   -18.01    -70.25
# 587                  Atar      MR           81.69    20.52    -13.05
# 588               Margate      AU            66.2   -43.03    147.26
# 589  Vila Franca do Campo      PT            71.6    37.72    -25.43
# 590               Camacha      PT           70.81    33.08    -16.33
# 591              Billings      US           71.96    45.79    -108.5
# 592               Lithgow      AU            78.8   -33.48    150.16
# 593                 Upata      VE           68.91     8.02    -62.41
# 594         Cockburn Town      TC           83.22    21.46    -71.14
#
#     Humidity (%) Cloudiness (%) Wind Speed (mph)
# 0            100              0             8.23
# 1            100              8             8.46
# 2             64             64            10.69
# 3            100             80            13.82
# 4             61              0             6.55
# 5            100             75             2.24
# 6             77              0             7.34
# 8             92             88             3.42
# 9             36              0            12.75
# 10            45             75            16.11
# 11            98             68             8.57
# 12            67             75             20.8
# 13           100             88             2.24
# 14            74             75            11.41
# 15           100              0            16.06
# 16            74             40            11.41
# 17            75             20              4.7
# 18            65             40            10.29
# 19            93              0              4.7
# 20            88             40            10.25
# 21            63              8             2.98
# 22            87              8             3.65
# 23           100             40              4.7
# 25            73              8                7
# 26            92              8             0.63
# 27            83             75             3.36
# 28            83              8             1.97
# 29           100             88             6.55
# 30            81             40              4.7
# 31            79             75              4.7
# ..           ...            ...              ...
# 564           68              1             2.86
# 565           82              0            13.87
# 566           61              0             2.19
# 567           97             92             2.98
# 568           98             88             7.56
# 569           77             36             5.77
# 570           63             20            16.73
# 571          100             92             6.89
# 572           82             90            11.41
# 573           93              0             3.36
# 574           71             68            12.37
# 576           92             92             18.3
# 577           99             88             2.64
# 578           80              0             2.19
# 579           77             75             3.36
# 580           83             20             2.53
# 581          100             75            16.11
# 582           32             88             8.34
# 583           96             20             1.41
# 584          100              8             0.63
# 585          100             92            11.25
# 586           87             90              4.7
# 587           40             20             4.21
# 588           45             75            16.11
# 589           94             75             5.82
# 590           77             40             8.05
# 591           30             20             8.05
# 592           31              0            14.99
# 593           99             68             2.75
# 594           97              0            10.13
#
# [542 rows x 8 columns]

# %%
#Reset the index
clean_cities_df = clean_cities_df.reset_index()
del clean_cities_df['index']
clean_cities_df.head(25)
# Out:
#                   City Country Temperature (F) Latitude Longitude  \
# 0              Rikitea      PF           73.41   -23.12   -134.97
# 1            Dhidhdhoo      MV           83.58     6.88      73.1
# 2    Nerchinskiy Zavod      RU           67.02    51.31    119.61
# 3            Busselton      AU           58.56   -33.64    115.35
# 4         Batemans Bay      AU           68.91   -35.71    150.18
# 5                Yatou      CM            75.2     3.63      9.81
# 6             Umm Lajj      SA           85.92    25.02     37.27
# 7          Cravo Norte      CO           75.84      6.3     -70.2
# 8              Yeppoon      AU              77   -23.13    150.74
# 9               Hobart      AU            66.2   -42.88    147.33
# 10          Port Blair      IN           83.13    11.67     92.75
# 11              Palmer      AU            60.8   -34.85    139.16
# 12            Klaksvik      FO            48.2    62.23     -6.59
# 13         San Quintin      PH              86    17.54    120.52
# 14              Atuona      PF           78.54     -9.8   -139.03
# 15                Hilo      US           67.87    19.71   -155.08
# 16             Ushuaia      AR            42.8   -54.81    -68.31
# 17            Katsuura      JP            78.8    33.93     134.5
# 18           Cape Town      ZA            42.8   -33.93     18.42
# 19      Cabo San Lucas      MX              77    22.89   -109.91
# 20     Haines Junction      CA           38.94    60.75   -137.51
# 21               Vaini      IN           78.45    15.34     74.49
# 22  Havre-Saint-Pierre      CA            37.4    50.23     -63.6
# 23             Mataura      NZ            48.3   -46.19    168.86
# 24            Mollendo      PE           48.39   -17.03    -72.02
#
#    Humidity (%) Cloudiness (%) Wind Speed (mph)
# 0           100              0             8.23
# 1           100              8             8.46
# 2            64             64            10.69
# 3           100             80            13.82
# 4            61              0             6.55
# 5           100             75             2.24
# 6            77              0             7.34
# 7            92             88             3.42
# 8            36              0            12.75
# 9            45             75            16.11
# 10           98             68             8.57
# 11           67             75             20.8
# 12          100             88             2.24
# 13           74             75            11.41
# 14          100              0            16.06
# 15           74             40            11.41
# 16           75             20              4.7
# 17           65             40            10.29
# 18           93              0              4.7
# 19           88             40            10.25
# 20           63              8             2.98
# 21           87              8             3.65
# 22          100             40              4.7
# 23           73              8                7
# 24           92              8             0.63

# %%
# Save data to a CSV file
output_data_file = clean_cities_df.to_csv ("../output_data/cities.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#scatter plot for Latitude vs. Temperature

plt.scatter(clean_cities_df["Latitude"], 
            clean_cities_df["Temperature (F)"], c=clean_cities_df["Temperature (F)"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='Spectral_r', alpha=0.8, label="City")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temperature (09/09/2018)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-60, 100])
plt.ylim([20, 100])

# Show plot
plt.show()

# %%
# Save the figure
plt.savefig("../images/Latitude_Temperature.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#scatter plot for Latitude vs. Humidity

plt.scatter(clean_cities_df["Latitude"], 
            clean_cities_df["Humidity (%)"], c=clean_cities_df["Humidity (%)"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='Spectral_r', alpha=0.8, label="City")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity (09/09/2018)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([0, 120])

# Show plot
plt.show()

# %%
# Save the figure
plt.savefig("../images/Latitude_Humidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#scatter plot for Latitude vs. Cloudiness (%)#Build a 

plt.scatter(clean_cities_df["Latitude"], 
            clean_cities_df["Cloudiness (%)"], c=clean_cities_df["Cloudiness (%)"],
            edgecolor="black", linewidths=0.5, marker="o", 
            cmap='Spectral_r', alpha=0.8, label="City")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness (09/09/2018)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-60, 80])
plt.ylim([-10, 110])

# Show plot
plt.show()

# %%
# Save the figure
plt.savefig("../images/Latitude_Cloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#scatter plot for Latitude vs. Wind Speed (mph)

plt.scatter(clean_cities_df["Latitude"], 
            clean_cities_df["Wind Speed (mph)"], c=clean_cities_df["Wind Speed (mph)"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='Spectral_r', alpha=0.8, label="City")

# Incorporate the other graph properties

plt.title(f"City Latitude vs. Wind Speed (09/09/2018)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-60, 80])
plt.ylim([0, 30])

# Show plot
plt.show()

# %%
# Save the figure
plt.savefig("../images/Latitude_Windspeed.png")
