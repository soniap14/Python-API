# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# Create a df to lat, lon 
column_names = ["City", "Country"]
cities_df = pd.DataFrame(columns=column_names)
cities_df
# Out:
# Empty DataFrame
# Columns: [City, Country]
# Index: []

# %% [markdown]
# ## Generate Cities List

# %%
# Randomly generate a list of 500 cities 
for x in range(500):
    lat, lng = np.random.uniform(low=-90.000, high=90.000), np.random.uniform(low=-180.000, high=180.000)
    city = citipy.nearest_city(lat, lng)
    cities_df = cities_df.append({"City": city.city_name,"Country": city.country_code,}, ignore_index=True)
cities_df.head()
# Out:
#            City Country
# 0     upernavik      gl
# 1  puerto ayora      ec
# 2    manchester      us
# 3     cape town      za
# 4       qaanaaq      gl

# %%
#Create a df to add all the data from the API calls.
column_names = ["City","Country","Temperature (F)",
                "Latitude","Longitude","Humidity (%)",
                "Cloudiness (%)", "Wind Speed (mph)"]
clean_cities_df = pd.DataFrame(columns=column_names)
clean_cities_df.head()
# Out:
# Empty DataFrame
# Columns: [City, Country, Temperature (F), Latitude, Longitude, Humidity (%), Cloudiness (%), Wind Speed (mph)]
# Index: []

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Loop through the list of cities and add the data to the df. 
url = "http://api.openweathermap.org/data/2.5/weather?"

row_count = 1

print("Beginning Data Retrieval")
for index, row in cities_df.iterrows():
    target_city = row["City"]
    target_url = url + "appid=" + api_key + "&units=IMPERIAL" + "&q=" + target_city.replace(" ","+")
    city_data = requests.get(target_url).json()
    if city_data["cod"] == "404":
        print("City not found, skipping...")

    else:
        clean_cities_df.set_value(index, "City", city_data["name"])
        clean_cities_df.set_value(index, "Country", city_data["sys"]["country"])
        clean_cities_df.set_value(index, "Temperature (F)", city_data["main"]["temp"])
        clean_cities_df.set_value(index, "Latitude", city_data["coord"]["lat"])
        clean_cities_df.set_value(index, "Longitude", city_data["coord"]["lon"])
        clean_cities_df.set_value(index, "Humidity (%)", city_data["main"]["humidity"])
        clean_cities_df.set_value(index, "Cloudiness (%)", city_data["clouds"]["all"])
        clean_cities_df.set_value(index, "Wind Speed (mph)", city_data["wind"]["speed"])
        
        print("------------------------")
        print("Proceesing: City # " , row_count, ' | ' , city_data["name"], city_data["sys"]["country"])
        print(target_url)
        row_count += 1
# Out:
# Beginning Data Retrieval
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:16: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   app.launch_new_instance()
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:20: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:21: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# ------------------------
# Proceesing: City #  1  |  Upernavik GL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=upernavik
# ------------------------
# Proceesing: City #  2  |  Puerto Ayora EC
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=puerto+ayora
# ------------------------
# Proceesing: City #  3  |  Manchester US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=manchester
# ------------------------
# Proceesing: City #  4  |  Cape Town ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=cape+town
# ------------------------
# Proceesing: City #  5  |  Qaanaaq GL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=qaanaaq
# ------------------------
# Proceesing: City #  6  |  Mar del Plata AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mar+del+plata
# City not found, skipping...
# ------------------------
# Proceesing: City #  7  |  Marsh Harbour BS
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=marsh+harbour
# ------------------------
# Proceesing: City #  8  |  Tarma PE
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=tarma
# ------------------------
# Proceesing: City #  9  |  Ushuaia AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ushuaia
# ------------------------
# Proceesing: City #  10  |  Chokurdakh RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=chokurdakh
# ------------------------
# Proceesing: City #  11  |  Bredasdorp ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=bredasdorp
# ------------------------
# Proceesing: City #  12  |  Saint-Philippe CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=saint-philippe
# ------------------------
# Proceesing: City #  13  |  Kodiak US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=kodiak
# City not found, skipping...
# ------------------------
# Proceesing: City #  14  |  Punta Arenas CL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=punta+arenas
# ------------------------
# Proceesing: City #  15  |  Aklavik CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=aklavik
# ------------------------
# Proceesing: City #  16  |  Ocampo PH
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ocampo
# ------------------------
# Proceesing: City #  17  |  Port Hardy CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=port+hardy
# ------------------------
# Proceesing: City #  18  |  Busselton AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=busselton
# ------------------------
# Proceesing: City #  19  |  Veinticinco de Mayo AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=veinticinco+de+mayo
# ------------------------
# Proceesing: City #  20  |  Nynashamn SE
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=nynashamn
# ------------------------
# Proceesing: City #  21  |  Ushuaia AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ushuaia
# ------------------------
# Proceesing: City #  22  |  Saint George GR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=saint+george
# ------------------------
# Proceesing: City #  23  |  Purpe RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=purpe
# ------------------------
# Proceesing: City #  24  |  Bredasdorp ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=bredasdorp
# ------------------------
# Proceesing: City #  25  |  Albany US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=albany
# ------------------------
# Proceesing: City #  26  |  Rawson AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=rawson
# ------------------------
# Proceesing: City #  27  |  Mataura NZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mataura
# ------------------------
# Proceesing: City #  28  |  Jamestown AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=jamestown
# ------------------------
# Proceesing: City #  29  |  Albany US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=albany
# ------------------------
# Proceesing: City #  30  |  Cherskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=cherskiy
# ------------------------
# Proceesing: City #  31  |  Lagos NG
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=lagos
# ------------------------
# Proceesing: City #  32  |  Cape Town ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=cape+town
# ------------------------
# Proceesing: City #  33  |  Port Alfred ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=port+alfred
# ------------------------
# Proceesing: City #  34  |  Saskylakh RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=saskylakh
# ------------------------
# Proceesing: City #  35  |  Pathardi IN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=pathardi
# ------------------------
# Proceesing: City #  36  |  Butaritari KI
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=butaritari
# ------------------------
# Proceesing: City #  37  |  Magadan RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=magadan
# ------------------------
# Proceesing: City #  38  |  Ushuaia AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ushuaia
# ------------------------
# Proceesing: City #  39  |  Yellowknife CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=yellowknife
# ------------------------
# Proceesing: City #  40  |  Grandview US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=grandview
# ------------------------
# Proceesing: City #  41  |  Kodiak US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=kodiak
# ------------------------
# Proceesing: City #  42  |  Cape Town ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=cape+town
# ------------------------
# Proceesing: City #  43  |  Chapais CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=chapais
# ------------------------
# Proceesing: City #  44  |  Zheleznodorozhnyy RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=zheleznodorozhnyy
# ------------------------
# Proceesing: City #  45  |  Albany US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=albany
# ------------------------
# Proceesing: City #  46  |  Leningradskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=leningradskiy
# ------------------------
# Proceesing: City #  47  |  Kodiak US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=kodiak
# ------------------------
# Proceesing: City #  48  |  Torbay CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=torbay
# ------------------------
# Proceesing: City #  49  |  Thompson CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=thompson
# ------------------------
# Proceesing: City #  50  |  Bulawayo ZW
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=bulawayo
# City not found, skipping...
# ------------------------
# Proceesing: City #  51  |  Iqaluit CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=iqaluit
# ------------------------
# Proceesing: City #  52  |  New Norfolk AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=new+norfolk
# ------------------------
# Proceesing: City #  53  |  Tutoia BR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=tutoia
# ------------------------
# Proceesing: City #  54  |  Bakchar RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=bakchar
# ------------------------
# Proceesing: City #  55  |  Sabha LY
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=sabha
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  56  |  Alofi NU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=alofi
# ------------------------
# Proceesing: City #  57  |  Ponta do Sol BR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ponta+do+sol
# ------------------------
# Proceesing: City #  58  |  Rikitea PF
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=rikitea
# ------------------------
# Proceesing: City #  59  |  Mountain Home US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mountain+home
# ------------------------
# Proceesing: City #  60  |  Puerto Ayora EC
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=puerto+ayora
# ------------------------
# Proceesing: City #  61  |  Tual ID
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=tual
# ------------------------
# Proceesing: City #  62  |  Berlevag NO
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=berlevag
# ------------------------
# Proceesing: City #  63  |  Toora-Khem RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=toora-khem
# ------------------------
# Proceesing: City #  64  |  Skelleftea SE
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=skelleftea
# ------------------------
# Proceesing: City #  65  |  Tasiilaq GL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=tasiilaq
# ------------------------
# Proceesing: City #  66  |  Cape Town ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=cape+town
# ------------------------
# Proceesing: City #  67  |  Airai TL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=airai
# ------------------------
# Proceesing: City #  68  |  Dunedin NZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=dunedin
# ------------------------
# Proceesing: City #  69  |  Bluff AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=bluff
# ------------------------
# Proceesing: City #  70  |  Bend US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=bend
# ------------------------
# Proceesing: City #  71  |  Kapaa US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=kapaa
# City not found, skipping...
# ------------------------
# Proceesing: City #  72  |  Hermanus ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=hermanus
# ------------------------
# Proceesing: City #  73  |  Georgetown GY
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=georgetown
# ------------------------
# Proceesing: City #  74  |  Ancud CL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ancud
# City not found, skipping...
# ------------------------
# Proceesing: City #  75  |  Tazovskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=tazovskiy
# ------------------------
# Proceesing: City #  76  |  Yulara AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=yulara
# City not found, skipping...
# ------------------------
# Proceesing: City #  77  |  Clarksville US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=clarksville
# ------------------------
# Proceesing: City #  78  |  Cidreira BR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=cidreira
# ------------------------
# Proceesing: City #  79  |  Pevek RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=pevek
# City not found, skipping...
# ------------------------
# Proceesing: City #  80  |  Saskylakh RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=saskylakh
# ------------------------
# Proceesing: City #  81  |  Arona IT
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=arona
# ------------------------
# Proceesing: City #  82  |  Ushuaia AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ushuaia
# ------------------------
# Proceesing: City #  83  |  Kapaa US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=kapaa
# ------------------------
# Proceesing: City #  84  |  Vaini IN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=vaini
# ------------------------
# Proceesing: City #  85  |  Punta Arenas CL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=punta+arenas
# ------------------------
# Proceesing: City #  86  |  Ushuaia AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ushuaia
# ------------------------
# Proceesing: City #  87  |  Batemans Bay AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=batemans+bay
# City not found, skipping...
# ------------------------
# Proceesing: City #  88  |  Koygorodok RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=koygorodok
# ------------------------
# Proceesing: City #  89  |  Qitaihe CN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=qitaihe
# ------------------------
# Proceesing: City #  90  |  Saint George GR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=saint+george
# ------------------------
# Proceesing: City #  91  |  Borazjan IR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=borazjan
# ------------------------
# Proceesing: City #  92  |  Annaka JP
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=annaka
# ------------------------
# Proceesing: City #  93  |  Ribeira Grande PT
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ribeira+grande
# ------------------------
# Proceesing: City #  94  |  Saint-Pierre FR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=saint-pierre
# ------------------------
# Proceesing: City #  95  |  Carnarvon ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=carnarvon
# ------------------------
# Proceesing: City #  96  |  Henties Bay NA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=henties+bay
# ------------------------
# Proceesing: City #  97  |  Bingerville CI
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=bingerville
# ------------------------
# Proceesing: City #  98  |  Jamestown AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=jamestown
# City not found, skipping...
# ------------------------
# Proceesing: City #  99  |  Wanning AT
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=wanning
# ------------------------
# Proceesing: City #  100  |  Bathsheba BB
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=bathsheba
# ------------------------
# Proceesing: City #  101  |  Longyearbyen NO
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=longyearbyen
# ------------------------
# Proceesing: City #  102  |  Lebu ET
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=lebu
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  103  |  Gazanjyk TM
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=gazanjyk
# ------------------------
# Proceesing: City #  104  |  Ushuaia AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ushuaia
# ------------------------
# Proceesing: City #  105  |  Kyzyl-Suu KG
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=kyzyl-suu
# ------------------------
# Proceesing: City #  106  |  Dikson RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=dikson
# City not found, skipping...
# ------------------------
# Proceesing: City #  107  |  Barrow AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=barrow
# ------------------------
# Proceesing: City #  108  |  Camacupa AO
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=camacupa
# ------------------------
# Proceesing: City #  109  |  Elko US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=elko
# ------------------------
# Proceesing: City #  110  |  Ushuaia AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ushuaia
# ------------------------
# Proceesing: City #  111  |  Albany US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=albany
# ------------------------
# Proceesing: City #  112  |  Bluff AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=bluff
# ------------------------
# Proceesing: City #  113  |  Bredasdorp ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=bredasdorp
# ------------------------
# Proceesing: City #  114  |  Bluff AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=bluff
# ------------------------
# Proceesing: City #  115  |  Puerto Ayora EC
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=puerto+ayora
# ------------------------
# Proceesing: City #  116  |  Havre-Saint-Pierre CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=havre-saint-pierre
# ------------------------
# Proceesing: City #  117  |  Ushuaia AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ushuaia
# ------------------------
# Proceesing: City #  118  |  Meulaboh ID
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=meulaboh
# ------------------------
# Proceesing: City #  119  |  Coquimbo CL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=coquimbo
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  120  |  Karratha AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=karratha
# ------------------------
# Proceesing: City #  121  |  Butaritari KI
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=butaritari
# ------------------------
# Proceesing: City #  122  |  Rikitea PF
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=rikitea
# ------------------------
# Proceesing: City #  123  |  Camacupa AO
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=camacupa
# City not found, skipping...
# ------------------------
# Proceesing: City #  124  |  Mataura NZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mataura
# ------------------------
# Proceesing: City #  125  |  Port Alfred ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=port+alfred
# ------------------------
# Proceesing: City #  126  |  Busselton AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=busselton
# ------------------------
# Proceesing: City #  127  |  Victoria BN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=victoria
# ------------------------
# Proceesing: City #  128  |  Quatre Cocos MU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=quatre+cocos
# ------------------------
# Proceesing: City #  129  |  Tuktoyaktuk CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=tuktoyaktuk
# ------------------------
# Proceesing: City #  130  |  Avarua CK
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=avarua
# ------------------------
# Proceesing: City #  131  |  Busselton AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=busselton
# ------------------------
# Proceesing: City #  132  |  Ushuaia AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ushuaia
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  133  |  Arraial do Cabo BR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=arraial+do+cabo
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  134  |  Grootfontein NA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=grootfontein
# ------------------------
# Proceesing: City #  135  |  Vila Franca do Campo PT
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=vila+franca+do+campo
# ------------------------
# Proceesing: City #  136  |  Mataura NZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mataura
# ------------------------
# Proceesing: City #  137  |  Ribeira Grande PT
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ribeira+grande
# ------------------------
# Proceesing: City #  138  |  Baghmara IN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=baghmara
# ------------------------
# Proceesing: City #  139  |  Albany US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=albany
# ------------------------
# Proceesing: City #  140  |  Cape Town ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=cape+town
# ------------------------
# Proceesing: City #  141  |  Rikitea PF
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=rikitea
# ------------------------
# Proceesing: City #  142  |  Krutinka RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=krutinka
# ------------------------
# Proceesing: City #  143  |  Hami CN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=hami
# ------------------------
# Proceesing: City #  144  |  Dikson RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=dikson
# ------------------------
# Proceesing: City #  145  |  Hobart AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=hobart
# ------------------------
# Proceesing: City #  146  |  Clarence Town AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=clarence+town
# ------------------------
# Proceesing: City #  147  |  Mataura NZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mataura
# ------------------------
# Proceesing: City #  148  |  Atuona PF
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=atuona
# ------------------------
# Proceesing: City #  149  |  Rikitea PF
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=rikitea
# ------------------------
# Proceesing: City #  150  |  Ushuaia AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ushuaia
# ------------------------
# Proceesing: City #  151  |  Laguna MX
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=laguna
# ------------------------
# Proceesing: City #  152  |  Santa Rosa AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=santa+rosa
# ------------------------
# Proceesing: City #  153  |  Tanout NE
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=tanout
# ------------------------
# Proceesing: City #  154  |  Hithadhoo MV
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=hithadhoo
# ------------------------
# Proceesing: City #  155  |  La Macarena CO
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=la+macarena
# ------------------------
# Proceesing: City #  156  |  Hovd NO
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=hovd
# ------------------------
# Proceesing: City #  157  |  Punta Arenas CL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=punta+arenas
# ------------------------
# Proceesing: City #  158  |  New Norfolk AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=new+norfolk
# ------------------------
# Proceesing: City #  159  |  Hobart AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=hobart
# City not found, skipping...
# ------------------------
# Proceesing: City #  160  |  Nizhniy Ingash RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=nizhniy+ingash
# ------------------------
# Proceesing: City #  161  |  Saint-Philippe CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=saint-philippe
# City not found, skipping...
# ------------------------
# Proceesing: City #  162  |  Alta NO
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=alta
# City not found, skipping...
# ------------------------
# Proceesing: City #  163  |  Cape Town ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=cape+town
# ------------------------
# Proceesing: City #  164  |  Port Lincoln AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=port+lincoln
# ------------------------
# Proceesing: City #  165  |  Lawrence US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=lawrence
# ------------------------
# Proceesing: City #  166  |  Aguazul CO
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=aguazul
# ------------------------
# Proceesing: City #  167  |  South River CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=south+river
# ------------------------
# Proceesing: City #  168  |  Leningradskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=leningradskiy
# ------------------------
# Proceesing: City #  169  |  Ojinaga US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ojinaga
# ------------------------
# Proceesing: City #  170  |  Port Lincoln AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=port+lincoln
# ------------------------
# Proceesing: City #  171  |  Cidreira BR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=cidreira
# ------------------------
# Proceesing: City #  172  |  Cape Town ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=cape+town
# ------------------------
# Proceesing: City #  173  |  Vaini IN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=vaini
# ------------------------
# Proceesing: City #  174  |  Hilo US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=hilo
# ------------------------
# Proceesing: City #  175  |  Rikitea PF
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=rikitea
# ------------------------
# Proceesing: City #  176  |  Albany US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=albany
# ------------------------
# Proceesing: City #  177  |  Mataura NZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mataura
# ------------------------
# Proceesing: City #  178  |  Bambous Virieux MU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=bambous+virieux
# ------------------------
# Proceesing: City #  179  |  Blairmore CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=blairmore
# ------------------------
# Proceesing: City #  180  |  Butaritari KI
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=butaritari
# ------------------------
# Proceesing: City #  181  |  Antofagasta CL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=antofagasta
# ------------------------
# Proceesing: City #  182  |  Butaritari KI
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=butaritari
# ------------------------
# Proceesing: City #  183  |  Cherskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=cherskiy
# ------------------------
# Proceesing: City #  184  |  Grindavik IS
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=grindavik
# ------------------------
# Proceesing: City #  185  |  Port Alfred ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=port+alfred
# ------------------------
# Proceesing: City #  186  |  Jamestown AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=jamestown
# ------------------------
# Proceesing: City #  187  |  Hermanus ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=hermanus
# ------------------------
# Proceesing: City #  188  |  Saskylakh RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=saskylakh
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  189  |  Victoria BN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=victoria
# City not found, skipping...
# ------------------------
# Proceesing: City #  190  |  Punta Arenas CL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=punta+arenas
# ------------------------
# Proceesing: City #  191  |  Huarmey PE
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=huarmey
# ------------------------
# Proceesing: City #  192  |  Galdar ES
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=galdar
# ------------------------
# Proceesing: City #  193  |  Sur OM
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=sur
# ------------------------
# Proceesing: City #  194  |  Fos-sur-Mer FR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=fos-sur-mer
# City not found, skipping...
# ------------------------
# Proceesing: City #  195  |  Jamestown AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=jamestown
# ------------------------
# Proceesing: City #  196  |  Nevsehir TR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=nevsehir
# ------------------------
# Proceesing: City #  197  |  Rio Gallegos AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=rio+gallegos
# ------------------------
# Proceesing: City #  198  |  Mataura NZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mataura
# ------------------------
# Proceesing: City #  199  |  Cabra ES
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=cabra
# ------------------------
# Proceesing: City #  200  |  Trairi BR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=trairi
# ------------------------
# Proceesing: City #  201  |  Jamestown AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=jamestown
# ------------------------
# Proceesing: City #  202  |  Ust-Maya RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ust-maya
# ------------------------
# Proceesing: City #  203  |  Isangel VU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=isangel
# ------------------------
# Proceesing: City #  204  |  Luderitz NA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=luderitz
# ------------------------
# Proceesing: City #  205  |  Kenai US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=kenai
# ------------------------
# Proceesing: City #  206  |  Oudtshoorn ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=oudtshoorn
# ------------------------
# Proceesing: City #  207  |  Vostok RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=vostok
# ------------------------
# Proceesing: City #  208  |  Ostrovnoy RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ostrovnoy
# ------------------------
# Proceesing: City #  209  |  Leh IN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=leh
# ------------------------
# Proceesing: City #  210  |  Esperance TT
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=esperance
# City not found, skipping...
# ------------------------
# Proceesing: City #  211  |  Vaini IN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=vaini
# ------------------------
# Proceesing: City #  212  |  Kaitangata NZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=kaitangata
# ------------------------
# Proceesing: City #  213  |  Ushuaia AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ushuaia
# ------------------------
# Proceesing: City #  214  |  Aasiaat GL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=aasiaat
# ------------------------
# Proceesing: City #  215  |  Atuona PF
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=atuona
# City not found, skipping...
# ------------------------
# Proceesing: City #  216  |  Cape Town ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=cape+town
# ------------------------
# Proceesing: City #  217  |  Ushuaia AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ushuaia
# ------------------------
# Proceesing: City #  218  |  Port Alfred ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=port+alfred
# ------------------------
# Proceesing: City #  219  |  Chuy UY
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=chuy
# ------------------------
# Proceesing: City #  220  |  Rikitea PF
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=rikitea
# City not found, skipping...
# ------------------------
# Proceesing: City #  221  |  Jamestown AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=jamestown
# ------------------------
# Proceesing: City #  222  |  Albany US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=albany
# ------------------------
# Proceesing: City #  223  |  Qaanaaq GL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=qaanaaq
# ------------------------
# Proceesing: City #  224  |  Valparaiso US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=valparaiso
# ------------------------
# Proceesing: City #  225  |  Yumen CN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=yumen
# ------------------------
# Proceesing: City #  226  |  Pochutla MX
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=pochutla
# ------------------------
# Proceesing: City #  227  |  Hilo US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=hilo
# City not found, skipping...
# ------------------------
# Proceesing: City #  228  |  Kaitangata NZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=kaitangata
# ------------------------
# Proceesing: City #  229  |  Mount Gambier AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mount+gambier
# ------------------------
# Proceesing: City #  230  |  Hami CN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=hami
# City not found, skipping...
# ------------------------
# Proceesing: City #  231  |  Vardo US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=vardo
# ------------------------
# Proceesing: City #  232  |  Puerto Ayora EC
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=puerto+ayora
# ------------------------
# Proceesing: City #  233  |  Moncton CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=moncton
# ------------------------
# Proceesing: City #  234  |  Stokmarknes NO
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=stokmarknes
# ------------------------
# Proceesing: City #  235  |  Khatanga RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=khatanga
# ------------------------
# Proceesing: City #  236  |  Najran SA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=najran
# ------------------------
# Proceesing: City #  237  |  New Norfolk AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=new+norfolk
# ------------------------
# Proceesing: City #  238  |  Ushuaia AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ushuaia
# ------------------------
# Proceesing: City #  239  |  Hasaki JP
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=hasaki
# ------------------------
# Proceesing: City #  240  |  Thompson CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=thompson
# ------------------------
# Proceesing: City #  241  |  Leningradskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=leningradskiy
# ------------------------
# Proceesing: City #  242  |  Khatanga RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=khatanga
# ------------------------
# Proceesing: City #  243  |  Nuevo Progreso US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=nuevo+progreso
# ------------------------
# Proceesing: City #  244  |  Orcopampa PE
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=orcopampa
# ------------------------
# Proceesing: City #  245  |  Rikitea PF
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=rikitea
# ------------------------
# Proceesing: City #  246  |  Albany US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=albany
# ------------------------
# Proceesing: City #  247  |  Ajaccio FR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ajaccio
# ------------------------
# Proceesing: City #  248  |  Mataura NZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mataura
# ------------------------
# Proceesing: City #  249  |  Saldanha PT
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=saldanha
# ------------------------
# Proceesing: City #  250  |  Sao Filipe CV
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=sao+filipe
# ------------------------
# Proceesing: City #  251  |  Kloulklubed PW
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=kloulklubed
# City not found, skipping...
# ------------------------
# Proceesing: City #  252  |  Shelburne CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=shelburne
# ------------------------
# Proceesing: City #  253  |  Faya SA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=faya
# City not found, skipping...
# ------------------------
# Proceesing: City #  254  |  Hermanus ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=hermanus
# ------------------------
# Proceesing: City #  255  |  Avarua CK
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=avarua
# ------------------------
# Proceesing: City #  256  |  Port-Gentil GA
# ...
# ------------------------
# Proceesing: City #  361  |  Hermanus ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=hermanus
# ------------------------
# Proceesing: City #  362  |  Kapaa US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=kapaa
# ------------------------
# Proceesing: City #  363  |  Rikitea PF
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=rikitea
# ------------------------
# Proceesing: City #  364  |  Victoria BN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=victoria
# ------------------------
# Proceesing: City #  365  |  Barmer IN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=barmer
# ------------------------
# Proceesing: City #  366  |  Provideniya RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=provideniya
# ------------------------
# Proceesing: City #  367  |  Hobart AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=hobart
# ------------------------
# Proceesing: City #  368  |  San Quintin PH
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=san+quintin
# ------------------------
# Proceesing: City #  369  |  Takoradi GH
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=takoradi
# ------------------------
# Proceesing: City #  370  |  Coquimbo CL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=coquimbo
# ------------------------
# Proceesing: City #  371  |  Gombong ID
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=gombong
# ------------------------
# Proceesing: City #  372  |  Khatanga RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=khatanga
# ------------------------
# Proceesing: City #  373  |  Port Alfred ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=port+alfred
# ------------------------
# Proceesing: City #  374  |  Maniitsoq GL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=maniitsoq
# ------------------------
# Proceesing: City #  375  |  Nador MA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=nador
# ------------------------
# Proceesing: City #  376  |  Butaritari KI
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=butaritari
# ------------------------
# Proceesing: City #  377  |  Yumen CN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=yumen
# ------------------------
# Proceesing: City #  378  |  Hobart AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=hobart
# ------------------------
# Proceesing: City #  379  |  Beloha MG
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=beloha
# ------------------------
# Proceesing: City #  380  |  Qaanaaq GL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=qaanaaq
# ------------------------
# Proceesing: City #  381  |  Padang ID
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=padang
# ------------------------
# Proceesing: City #  382  |  Mataura NZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mataura
# ------------------------
# Proceesing: City #  383  |  Hamilton CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=hamilton
# ------------------------
# Proceesing: City #  384  |  Barrow AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=barrow
# ------------------------
# Proceesing: City #  385  |  Bijie CN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=bijie
# ------------------------
# Proceesing: City #  386  |  Mataura NZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mataura
# City not found, skipping...
# ------------------------
# Proceesing: City #  387  |  Carrick-on-Suir IE
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=carrick-on-suir
# ------------------------
# Proceesing: City #  388  |  Dunedin NZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=dunedin
# ------------------------
# Proceesing: City #  389  |  Lagoa PT
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=lagoa
# ------------------------
# Proceesing: City #  390  |  Muroto JP
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=muroto
# ------------------------
# Proceesing: City #  391  |  Hilo US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=hilo
# ------------------------
# Proceesing: City #  392  |  Torbay CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=torbay
# ------------------------
# Proceesing: City #  393  |  Acapulco MX
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=acapulco
# ------------------------
# Proceesing: City #  394  |  Georgetown GY
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=georgetown
# ------------------------
# Proceesing: City #  395  |  Yellowknife CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=yellowknife
# ------------------------
# Proceesing: City #  396  |  Mataura NZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mataura
# ------------------------
# Proceesing: City #  397  |  Qaanaaq GL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=qaanaaq
# ------------------------
# Proceesing: City #  398  |  Ormara PK
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ormara
# ------------------------
# Proceesing: City #  399  |  Sabha LY
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=sabha
# ------------------------
# Proceesing: City #  400  |  Chuy UY
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=chuy
# ------------------------
# Proceesing: City #  401  |  Fountain Hills US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=fountain+hills
# ------------------------
# Proceesing: City #  402  |  Sitka US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=sitka
# City not found, skipping...
# ------------------------
# Proceesing: City #  403  |  Georgetown GY
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=georgetown
# ------------------------
# Proceesing: City #  404  |  Bluff AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=bluff
# ------------------------
# Proceesing: City #  405  |  Cape Town ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=cape+town
# ------------------------
# Proceesing: City #  406  |  Ushuaia AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ushuaia
# ------------------------
# Proceesing: City #  407  |  Chimbarongo CL
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=chimbarongo
# City not found, skipping...
# ------------------------
# Proceesing: City #  408  |  Rikitea PF
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=rikitea
# City not found, skipping...
# ------------------------
# Proceesing: City #  409  |  Mnogovershinnyy RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mnogovershinnyy
# City not found, skipping...
# ------------------------
# Proceesing: City #  410  |  Aketi CD
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=aketi
# ------------------------
# Proceesing: City #  411  |  Hobart AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=hobart
# ------------------------
# Proceesing: City #  412  |  Barrow AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=barrow
# ------------------------
# Proceesing: City #  413  |  Sur OM
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=sur
# ------------------------
# Proceesing: City #  414  |  Egvekinot RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=egvekinot
# ------------------------
# Proceesing: City #  415  |  Yellowknife CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=yellowknife
# ------------------------
# Proceesing: City #  416  |  Turukhansk RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=turukhansk
# ------------------------
# Proceesing: City #  417  |  Dikson RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=dikson
# ------------------------
# Proceesing: City #  418  |  Bredasdorp ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=bredasdorp
# ------------------------
# Proceesing: City #  419  |  Mujiayingzi CN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mujiayingzi
# ------------------------
# Proceesing: City #  420  |  Koumac NC
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=koumac
# ------------------------
# Proceesing: City #  421  |  Vangaindrano MG
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=vangaindrano
# ------------------------
# Proceesing: City #  422  |  Saskylakh RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=saskylakh
# ------------------------
# Proceesing: City #  423  |  Busselton AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=busselton
# ------------------------
# Proceesing: City #  424  |  Albany US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=albany
# ------------------------
# Proceesing: City #  425  |  Ushuaia AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ushuaia
# ------------------------
# Proceesing: City #  426  |  Port Alfred ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=port+alfred
# ------------------------
# Proceesing: City #  427  |  Ushuaia AR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ushuaia
# ------------------------
# Proceesing: City #  428  |  Port Blair IN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=port+blair
# ------------------------
# Proceesing: City #  429  |  Geraldton CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=geraldton
# ------------------------
# Proceesing: City #  430  |  Kapaa US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=kapaa
# ------------------------
# Proceesing: City #  431  |  Beringovskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=beringovskiy
# ------------------------
# Proceesing: City #  432  |  Klaksvik FO
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=klaksvik
# ------------------------
# Proceesing: City #  433  |  Vaini IN
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=vaini
# ------------------------
# Proceesing: City #  434  |  Arkhangelsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=arkhangelsk
# ------------------------
# Proceesing: City #  435  |  Carnarvon ZA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=carnarvon
# ------------------------
# Proceesing: City #  436  |  Omboue GA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=omboue
# ------------------------
# Proceesing: City #  437  |  Busselton AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=busselton
# ------------------------
# Proceesing: City #  438  |  Cabo San Lucas MX
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=cabo+san+lucas
# ------------------------
# Proceesing: City #  439  |  Portland US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=portland
# ------------------------
# Proceesing: City #  440  |  Busselton AU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=busselton
# ------------------------
# Proceesing: City #  441  |  Bambous Virieux MU
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=bambous+virieux
# ------------------------
# Proceesing: City #  442  |  Vestmannaeyjar IS
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=vestmannaeyjar
# ------------------------
# Proceesing: City #  443  |  Ponta do Sol BR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ponta+do+sol
# ------------------------
# Proceesing: City #  444  |  Mataura NZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mataura
# ------------------------
# Proceesing: City #  445  |  Port Arthur US
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=port+arthur
# City not found, skipping...
# ------------------------
# Proceesing: City #  446  |  Maceio BR
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=maceio
# ------------------------
# Proceesing: City #  447  |  Lebu ET
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=lebu
# ------------------------
# Proceesing: City #  448  |  Ucluelet CA
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=ucluelet
# ------------------------
# Proceesing: City #  449  |  Mataura NZ
# http://api.openweathermap.org/data/2.5/weather?appid=4d0de241d02dabb93cd2fbbf60c865a6&units=IMPERIAL&q=mataura

# %%
clean_cities_df
# Out:
#                     City Country Temperature (F) Latitude Longitude  \
# 0              Upernavik      GL           37.44    72.79    -56.15
# 1           Puerto Ayora      EC              77    -0.74    -90.35
# 2             Manchester      US           61.72       43    -71.45
# 3              Cape Town      ZA            57.2   -33.93     18.42
# 4                Qaanaaq      GL           33.75    77.48    -69.36
# 5          Mar del Plata      AR           61.56   -46.43    -67.52
# 7          Marsh Harbour      BS           83.88    26.54    -77.06
# 8                  Tarma      PE           50.31   -11.42    -75.69
# 9                Ushuaia      AR           49.78   -54.81    -68.31
# 10            Chokurdakh      RU           48.06    70.62     147.9
# 11            Bredasdorp      ZA              50   -34.53     20.04
# 12        Saint-Philippe      CA            62.8    45.36    -73.48
# 13                Kodiak      US           80.06    39.95    -94.76
# 15          Punta Arenas      CL           43.75   -53.16    -70.91
# 16               Aklavik      CA            35.6    68.22   -135.01
# 17                Ocampo      PH           77.58    13.56    123.37
# 18            Port Hardy      CA            55.4     50.7   -127.42
# 19             Busselton      AU           54.63   -33.64    115.35
# 20   Veinticinco de Mayo      AR           77.13   -27.38    -54.75
# 21             Nynashamn      SE            55.4     58.9     17.95
# 22               Ushuaia      AR           49.78   -54.81    -68.31
# 23          Saint George      GR            71.6    39.45     22.34
# 24                 Purpe      RU           31.05    64.48     76.69
# 25            Bredasdorp      ZA              50   -34.53     20.04
# 26                Albany      US           57.38    42.65    -73.75
# 27                Rawson      AR           61.83    -43.3    -65.11
# 28               Mataura      NZ           45.09   -46.19    168.86
# 29             Jamestown      AU           53.91   -33.21     138.6
# 30                Albany      US           57.38    42.65    -73.75
# 31              Cherskiy      RU           54.45    68.75     161.3
# ..                   ...     ...             ...      ...       ...
# 469               Koumac      NC           67.23   -20.56    164.28
# 470         Vangaindrano      MG           66.78   -23.35      47.6
# 471            Saskylakh      RU           23.13    71.97    114.09
# 472            Busselton      AU           54.63   -33.64    115.35
# 473               Albany      US           57.38    42.65    -73.75
# 474              Ushuaia      AR           49.78   -54.81    -68.31
# 475          Port Alfred      ZA           60.66   -33.59     26.89
# 476              Ushuaia      AR           49.78   -54.81    -68.31
# 477           Port Blair      IN            82.8    11.67     92.75
# 478            Geraldton      CA            62.6    49.72    -86.95
# 479                Kapaa      US           80.08    22.08   -159.32
# 480         Beringovskiy      RU           54.54    63.05    179.32
# 481             Klaksvik      FO            48.2    62.23     -6.59
# 482                Vaini      IN            65.7    15.34     74.49
# 483          Arkhangelsk      RU            42.8    64.54     40.54
# 484            Carnarvon      ZA           31.32   -30.97     22.13
# 485               Omboue      GA           77.31    -1.57      9.26
# 486            Busselton      AU           54.63   -33.64    115.35
# 487       Cabo San Lucas      MX           83.48    22.89   -109.91
# 488             Portland      US           67.84    45.52   -122.67
# 489            Busselton      AU           54.63   -33.64    115.35
# 490      Bambous Virieux      MU            71.6   -20.34     57.76
# 491       Vestmannaeyjar      IS            45.9    63.44    -20.27
# 492         Ponta do Sol      BR           76.41   -20.63       -46
# 493              Mataura      NZ           45.09   -46.19    168.86
# 494          Port Arthur      US           77.47     29.9    -93.93
# 496               Maceio      BR              77    -9.67    -35.74
# 497                 Lebu      ET           48.42     8.96     38.73
# 498             Ucluelet      CA            57.2    48.94   -125.55
# 499              Mataura      NZ           45.09   -46.19    168.86
#
#     Humidity (%) Cloudiness (%) Wind Speed (mph)
# 0            100             64             7.52
# 1             65             20             20.8
# 2             86             90             5.82
# 3             87              0            10.29
# 4             96             76             6.51
# 5             36             48            14.79
# 7            100             48             2.48
# 8             65             56              1.7
# 9             40              0            11.41
# 10            62             48            11.43
# 11            87              0             1.12
# 12            48             75            12.75
# 13            50              1             8.05
# 15            75             75             5.82
# 16            99             75            10.29
# 17           100             24             4.16
# 18            93             90            13.87
# 19           100             44             14.9
# 20            52              0              8.3
# 21           100              0             2.24
# 22            40              0            11.41
# 23            53             20             4.94
# 24            89              0               13
# 25            87              0             1.12
# 26            86             90             3.36
# 27            47             48            24.07
# 28            95             76             8.63
# 29            40              0            15.01
# 30            86             90             3.36
# 31            58             64             5.73
# ..           ...            ...              ...
# 469           84              0             7.96
# 470           89             36             6.62
# 471           81              0              6.4
# 472          100             44             14.9
# 473           86             90             3.36
# 474           40              0            11.41
# 475           95              0             10.2
# 476           40              0            11.41
# 477           97             92            10.09
# 478           63             90            13.87
# 479           82              1             8.05
# 480           94              0            10.09
# 481          100             76              4.7
# 482           96             24             2.59
# 483          100             20             4.47
# 484           47              0             3.38
# 485           99             92             7.96
# 486          100             44             14.9
# 487           78             40             9.17
# 488           50             90             5.82
# 489          100             44             14.9
# 490           73             40             9.17
# 491          100             20             5.95
# 492           37             24             2.04
# 493           95             76             8.63
# 494           87             90             5.82
# 496           69             75            12.75
# 497           84             36             2.26
# 498           93             90             5.82
# 499           95             76             8.63
#
# [449 rows x 8 columns]

# %%
clean_cities_df.count()
# Out:
# City                449
# Country             449
# Temperature (F)     449
# Latitude            449
# Longitude           449
# Humidity (%)        449
# Cloudiness (%)      449
# Wind Speed (mph)    449
# dtype: int64

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
